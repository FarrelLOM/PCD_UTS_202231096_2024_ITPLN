# %% [markdown]
# # Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Menyiapkan gambar

# %%
img = cv2.imread("gambar2.jpg")
(baris, kolom) = img.shape[:2]
img.shape #untuk mengetahui dimensi gambar (p x l x t)
# Out:
# (543, 800, 3)

# %% [markdown]
# # CITRA KONTRAS

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
# Cara 1
fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(img)
axs[0,1].hist(img.ravel(),256,[0,256])

# Cara 2
hist = cv2.calcHist([img],[0],None,[256],[0,256])
axs[1,0].imshow(img)
axs[1,1].plot(hist)
plt.show()

# %% [markdown]
# # menaikkan kontras citra

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
#Menaikkan kontrass
beta = 200                                 #variabel indikator level kontrass 1-256
citra_cerah = np.zeros((baris, kolom, 3))

for x in range(baris) :
    for y in range(kolom) :
        gyx = img[x,y] + beta
        citra_cerah[x,y] = gyx
        
citra_cerah = citra_cerah.astype(np.uint8)

fig, axs = plt.subplots(2,2, figsize = (15,5))
axs[0,0].imshow(img)
axs[0,1].hist(img.ravel(),256,[0,256])
axs[1,0].imshow(citra_cerah)
axs[1,1].hist(citra_cerah.ravel(),256,[0,256])
plt.show()

# %%
# Konversi warna dari BGR (Blue, Green, Red) ke HSV (Hue, Saturation, Value) untuk menyiapkan filter deteksi warna
BGR = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
gry = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
waw = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('rgb',waw)
cv2.waitKey(0)

# %% [markdown]
# # Deteksi warna merah

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Baca citra
image = cv2.imread('gambar2.jpg')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Konversi citra ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# Tentukan rentang warna merah dalam HSV
lower_red1 = np.array([0, 100, 100])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([160, 100, 100])
upper_red2 = np.array([179, 255, 255])

# Buat mask untuk warna merah
mask_red1 = cv2.inRange(hsv, lower_red1, upper_red1)
mask_red2 = cv2.inRange(hsv, lower_red2, upper_red2)
mask_red = cv2.bitwise_or(mask_red1, mask_red2)

# Buat mask untuk semua warna kecuali merah
mask_not_red = cv2.bitwise_not(mask_red)

# Mutihkan semua warna kecuali merah pada gambar asli
whitened_image = cv2.bitwise_and(image, image, mask=mask_not_red)
    
# Hitamkan area yang terdeteksi dalam gambar asli
whitened_image = image.copy()
whitened_image[(mask_not_red != 0)]= [255, 255, 255]    #agar selain warna merah diputihkan (background)

# Tampilkan gambar asli dan yang telah dimutihkan beserta histogramnya
fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(image)
axs[0,1].hist(image.ravel(),256,[0,256])
hist = cv2.calcHist([whitened_image],[0],None,[256],[0,256])
axs[1,0].imshow(whitened_image)
axs[1,1].plot(hist)
plt.show()

# %% [markdown]
# # Warna hijau

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Baca citra
image = cv2.imread('gambar2.jpg')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Konversi citra ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# Tentukan rentang warna hijau dalam HSV
lower_green = np.array([35, 100, 100])
upper_green = np.array([90, 255, 255])

# Buat mask untuk warna hijau
mask_green = cv2.inRange(hsv, lower_green, upper_green)

# Buat mask untuk semua warna kecuali hijau
mask_not_green = cv2.bitwise_not(mask_green)

# Mutihkan semua warna kecuali hijau pada gambar asli
whitened_image = cv2.bitwise_and(image, image, mask=mask_not_green)
    
# Hitamkan area yang terdeteksi dalam gambar asli
whitened_image = image.copy()
whitened_image[(mask_not_green != 0)]= [255, 255, 255]       #agar selain warna hijau diputihkan (background)

# Tampilkan gambar asli dan yang telah dimutihkan beserta histogramnya
fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(image)
axs[0,1].hist(image.ravel(),256,[0,256])
hist = cv2.calcHist([whitened_image],[0],None,[256],[0,256])
axs[1,0].imshow(whitened_image)
axs[1,1].plot(hist)
plt.show()

# %% [markdown]
# # Warna Biru

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Baca citra
image = cv2.imread('gambar2.jpg')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Konversi citra ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# Tentukan rentang warna biru dalam HSV
lower_blue = np.array([90, 50, 50])
upper_blue = np.array([130, 255, 255])

# Buat mask untuk warna biru
mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)

# Buat mask untuk semua warna kecuali biru
mask_not_blue = cv2.bitwise_not(mask_blue)

# Mutihkan semua warna kecuali biru pada gambar asli
whitened_image = cv2.bitwise_and(image, image, mask=mask_not_blue)
    
# Hitamkan area yang terdeteksi dalam gambar asli
whitened_image = image.copy()
whitened_image[(mask_not_blue != 0)]= [255, 255, 255]        #agar selain warna biru diputihkan (background)

# Tampilkan gambar asli dan yang telah dimutihkan beserta histogramnya
fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(image)
axs[0,1].hist(image.ravel(),256,[0,256])
hist = cv2.calcHist([whitened_image],[0],None,[256],[0,256])
axs[1,0].imshow(whitened_image)
axs[1,1].plot(hist)
plt.show()

# %% [markdown]
# # Ambang batas citra biru

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Fungsi untuk mencari nilai ambang batas warna biru
def find_blue_threshold (image):
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0], None, [180], [0, 180])
    blue_threshold  = np.argmax(hist)
    return blue_threshold 

# Baca citra
image = cv2.imread('gambar2.jpg')

# Mencari nilai ambang batas warna biru
blue_threshold = find_blue_threshold(image)

# Konversi citra ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Tentukan rentang warna biru dalam HSV
lower_blue = np.array([90, 50, 50])
upper_blue = np.array([130, 255, 255])

# Buat mask untuk warna biru
mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)

# Buat mask untuk semua warna kecuali biru
mask_not_blue = cv2.bitwise_not(mask_blue)

# Mutihkan semua warna kecuali biru pada gambar asli
whitened_image = cv2.bitwise_and(image, image, mask=mask_not_blue)
whitened_image[mask_not_blue != 0] = [255, 255, 255]

# Tampilkan histogram
plt.hist(image.ravel(),256,[0,256])
hist = cv2.calcHist([whitened_image],[0],None,[256],[0,256])
plt.plot(hist)
plt.xlabel('Hue Value')
plt.ylabel('Frequency')
plt.title('Histogram Warna Biru')
plt.show()

# Tampilkan gambar asli dan yang telah dimutihkan
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axs[0].set_title('Citra Asli')
axs[1].imshow(cv2.cvtColor(whitened_image, cv2.COLOR_BGR2RGB))
axs[1].set_title('Hanya Warna Putih')
plt.show()
print("Ambang batas warna biru:", blue_threshold)
# Out:
# Ambang batas warna biru: 75

# %% [markdown]
# # ambang batas merah

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Baca citra
image = cv2.imread('gambar2.jpg')

# Fungsi untuk mencari nilai ambang batas warna merah
def find_red_threshold(image):
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0], None, [180], [0, 180])
    red_threshold  = np.argmax(hist)
    return red_threshold

# Mencari nilai ambang batas warna merah
red_threshold = find_red_threshold(image)

# Konversi citra ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Tentukan rentang warna merah dalam HSV
lower_red1 = np.array([0, 100, 100])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([160, 100, 100])
upper_red2 = np.array([179, 255, 255])

# Buat mask untuk warna merah
mask_red1 = cv2.inRange(hsv, lower_red1, upper_red1)
mask_red2 = cv2.inRange(hsv, lower_red2, upper_red2)
mask_red = cv2.bitwise_or(mask_red1, mask_red2)

# Buat mask untuk semua warna kecuali merah
mask_not_red = cv2.bitwise_not(mask_red)

# Mutihkan semua warna kecuali merah pada gambar asli
whitened_image = cv2.bitwise_and(image, image, mask=mask_not_red)
whitened_image[mask_not_red != 0] = [255, 255, 255]

# Tampilkan histogram
plt.hist(image.ravel(),256,[0,256])
hist = cv2.calcHist([whitened_image],[0],None,[256],[0,256])
plt.plot(hist)
plt.xlabel('Hue Value')
plt.ylabel('Frequency')
plt.title('Histogram Warna Merah')
plt.show()

# Tampilkan gambar asli dan yang telah dimutihkan
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axs[0].set_title('Citra Asli')
axs[1].imshow(cv2.cvtColor(whitened_image, cv2.COLOR_BGR2RGB))
axs[1].set_title('Hanya Warna Putih')
plt.show()
print("Ambang batas warna merah:", red_threshold )
# Out:
# Ambang batas warna merah: 75

# %% [markdown]
# # ambang batas warna hijau

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Fungsi untuk mencari nilai ambang batas warna hijau
def find_green_threshold(image):
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0], None, [180], [0, 180])
    green_threshold = np.argmax(hist)
    return green_threshold

# Baca citra
image = cv2.imread('gambar2.jpg')

# Mencari nilai ambang batas warna hijau
green_threshold = find_green_threshold(image)

# Konversi citra ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Tentukan rentang warna hijau dalam HSV
lower_green = np.array([35, 100, 100])
upper_green = np.array([90, 255, 255])

# Buat mask untuk warna hijau
mask_green = cv2.inRange(hsv, lower_green, upper_green)

# Buat mask untuk semua warna kecuali hijau
mask_not_green = cv2.bitwise_not(mask_green)

# Mutihkan semua warna kecuali hijau pada gambar asli
whitened_image = cv2.bitwise_and(image, image, mask=mask_not_green)
whitened_image[mask_not_green != 0] = [255, 255, 255]

# Tampilkan histogram
plt.hist(image.ravel(),256,[0,256])
hist = cv2.calcHist([whitened_image],[0],None,[256],[0,256])
plt.plot(hist)
plt.xlabel('Hue Value')
plt.ylabel('Frequency')
plt.title('Histogram Warna hijau')
plt.show()

# Tampilkan gambar asli dan yang telah dimutihkan
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axs[0].set_title('Citra Asli')
axs[1].imshow(cv2.cvtColor(whitened_image, cv2.COLOR_BGR2RGB))
axs[1].set_title('Hanya Warna Putih')
plt.show()
print("Ambang batas warna hijau:", green_threshold)
# Out:
# Ambang batas warna hijau: 75
